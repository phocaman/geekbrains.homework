# %% [markdown]
# # Домашнее задание

# %% [markdown]
# 1. Можно ли отобрать наиболее значимые признаки с помощью PCA?

# %% [markdown]
# Мне кажется, что нельзя, поскольку PCA предназначен для уменьшения размерности данных, т. е. сокращения количества признаков. Для отбора наиболее значимых признаков (feature importances) лучше использовать, например, ансамблевые алгоритмы на основе деревьев решений или L1-регуляризацию.

# %% [markdown]
# 2. (\*) Написать свою реализацию метода главных компонент с помощью сингулярного разложения с использованием функции [numpy.linalg.svd()](https://docs.scipy.org/doc/numpy/reference/generated/numpy.linalg.svd.html)

# %%
import numpy as np
from sklearn import datasets
import matplotlib.pyplot as plt

# %%
iris = datasets.load_iris()
X = iris.data
X_ = X.astype(float)

# %%
def svd(X):
  n, m = X.shape
  U, sigma, Vh = np.linalg.svd(X, full_matrices=False, compute_uv=True)
  X_svd = np.dot(U, np.diag(sigma))
  return X_svd

# %%
Z = svd(X_)

# %%
plt.figure()
y = iris.target
for c, i in zip('rgb', [0, 1, 2]):
    plt.scatter(Z[y==i, 0], Z[y==i, 1], c=c)
plt.xlabel('Principal component 1')
plt.ylabel('Principal component 2')
plt.title('IRIS Principal Component Analysis')
plt.show()
