# %%
# 1. Установить, какие произведения матриц  𝐴𝐵  и  𝐵𝐴  определены, и найти размерности полученных матриц:
# а) 𝐴 — матрица 4×2, 𝐵 — матрица 4×2;
# б) 𝐴 — матрица 2×5, 𝐵 — матрица 5×3;
# в) 𝐴 — матрица 8×3, 𝐵 — матрица 3×8;
# г) 𝐴 — квадратная матрица 4×4, 𝐵 — квадратная матрица 4×4.

# а) 𝐴 — матрица 4×2, 𝐵 — матрица 4×2:
# Произведения AB и BA не определены.

# б) 𝐴 — матрица 2×5, 𝐵 — матрица 5×3:
# Произведение AB определено, размерность 2 х 3. Произведение BA не определено.

# в) 𝐴 — матрица 8×3, 𝐵 — матрица 3×8:
# Произведение AB определено, размерность 8 х 8. Произведение AB определено, размерность 3 х 3.

# г) 𝐴 — квадратная матрица 4×4, 𝐵 — квадратная матрица 4×4:
# Произведения AB и BA определены, размерность 4 х 4.
